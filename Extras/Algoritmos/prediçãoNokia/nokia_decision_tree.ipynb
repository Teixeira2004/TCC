# %%
# Importando as bibliotecas necessárias
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import cross_val_score

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# Carregando o arquivo CSV da Asus
file_path = 'gdrive/My Drive/dados_smartphones_v4_Nokia_tratado.csv'
df_nokia = pd.read_csv(file_path, sep=";")

# %%
print(df_nokia.columns)

# %%
# Dividindo a variavel dependnete (Selling Price Dolar) -y- e as variáveis independentes (Memory e Storage) -x-
y = df_nokia['selling_price_dolar']
x = df_nokia.drop('selling_price_dolar',axis=1)

# %%
# Codificando a variável dependente Selling Price Dolar em categorias numéricas
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# %%
# Verificando o número de amostras disponíveis após o processamento
print("\nTotal de amostras disponíveis para treino e teste:", len(x))

# %%
# Dividindo o conjunto de dados em treino e teste
from sklearn.model_selection import train_test_split
x_treino, x_teste, y_treino, y_teste = train_test_split(x,y,test_size=0.3)

# %%
# Treinando o modelo DecisionTreeClassifier
model_dt = DecisionTreeClassifier(random_state=1986, criterion='gini', max_depth=3)
model_dt.fit(x_treino, y_treino)

# %%
# Previsões e avaliação do modelo
y_pred_dt = model_dt.predict(x_teste)
accuracy_dt = accuracy_score(y_teste, y_pred_dt)
classification_report_dt = classification_report(y_teste, y_pred_dt, target_names=label_encoder.classes_.astype(str))

# %%
# Exibindo os resultados
print("\nAcurácia do modelo DecisionTree:", accuracy_dt)
print("\nRelatório de Classificação do modelo DecisionTree:\n", classification_report_dt)

# %%
# Situações misteriosas adicionais para teste
#                      [memory, storage]
situacao_misterio1 = [2, 16]    # esperado: 1
situacao_misterio2 = [4, 64]    # esperado: 3
situacao_misterio3 = [1, 8]     # esperado: 1
situacao_misterio4 = [3, 32]    # esperado: 2
situacao_misterio5 = [4, 128]   # esperado: 2
situacao_misterio6 = [6, 64]    # esperado: 2
situacao_misterio7 = [6, 128]   # esperado: 3
situacao_misterio8 = [3, 64]   # esperado: 2
situacao_misterio9 = [3, 16]    # esperado: 3
situacao_misterio10 = [1, 4]    # esperado: 3

situacoes_misteriosas = [situacao_misterio1, situacao_misterio2, situacao_misterio3, situacao_misterio4, situacao_misterio5, situacao_misterio6, situacao_misterio7, situacao_misterio8, situacao_misterio9, situacao_misterio10]
previsoes = model_dt.predict(situacoes_misteriosas)
previsoes
#[1 3 1 2 2 2 3 2 3 3]

# %%
df_nokia.head(100)
