# %%
# Importando as bibliotecas necessárias
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import cross_val_score

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Carregando o arquivo CSV da Asus
file_path = 'gdrive/My Drive/dados_smartphones_v4_Motorola_tratado.csv'
df_motorola = pd.read_csv(file_path, sep=";")

# %%
print(df_motorola.columns)
# Out:
# Index(['memory', 'storage', 'selling_price_dolar'], dtype='object')

# %%
# Dividindo a variavel dependnete (Selling Price Dolar) -y- e as variáveis independentes (Memory e Storage) -x-
y = df_motorola['selling_price_dolar']
x = df_motorola.drop('selling_price_dolar',axis=1)

# %%
# Codificando a variável dependente Selling Price Dolar em categorias numéricas
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# %%
# Verificando o número de amostras disponíveis após o processamento
print("\nTotal de amostras disponíveis para treino e teste:", len(x))
# Out:
# Total de amostras disponíveis para treino e teste: 111

# %%
# Dividindo o conjunto de dados em treino e teste
from sklearn.model_selection import train_test_split
x_treino, x_teste, y_treino, y_teste = train_test_split(x,y,test_size=0.3)

# %%
# Treinando o modelo KNeighborsClassifier
model_knn = KNeighborsClassifier(n_neighbors=5)
model_knn.fit(x_treino, y_treino)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=1986)

# %%
# Previsões e avaliação do modelo
y_pred_knn = model_knn.predict(x_teste)
accuracy_knn = accuracy_score(y_teste, y_pred_knn)
classification_report_knn = classification_report(y_teste, y_pred_knn, target_names=label_encoder.classes_.astype(str))

# %%
# Exibindo os resultados
print("\nAcurácia do modelo KNeighborsClassifier:", accuracy_knn)
print("\nRelatório de Classificação do modelo KNeighborsClassifier:\n", classification_report_knn)
# Out:
# Acurácia do modelo DecisionTree: 0.7941176470588235
#
# Relatório de Classificação do modelo DecisionTree:
#                precision    recall  f1-score   support
#
#            1       0.80      0.92      0.86        13
#            2       0.78      0.64      0.70        11
#            3       0.80      0.80      0.80        10
#
#     accuracy                           0.79        34
#    macro avg       0.79      0.79      0.79        34
# weighted avg       0.79      0.79      0.79        34

# %%
# Situações misteriosas adicionais para teste
#                      [memory, storage]
situacao_misterio1 = [3, 32]    # esperado: 3
situacao_misterio2 = [1, 16]    # esperado: 3
situacao_misterio3 = [4, 64]    # esperado: 3
situacao_misterio4 = [2, 32]    # esperado: 3
situacao_misterio5 = [4, 128]   # esperado: 2
situacao_misterio6 = [2, 16]    # esperado: 1
situacao_misterio7 = [6, 128]   # esperado: 3
situacao_misterio8 = [8, 128]   # esperado: 3
situacao_misterio9 = [4, 32]    # esperado: 1
situacao_misterio10 = [12, 256] # esperado: 3

situacoes_misteriosas = [situacao_misterio1, situacao_misterio2, situacao_misterio3, situacao_misterio4, situacao_misterio5, situacao_misterio6, situacao_misterio7, situacao_misterio8, situacao_misterio9, situacao_misterio10]
previsoes = model_dt.predict(situacoes_misteriosas)
previsoes

#[3, 3, 3, 3, 2, 1, 3, 3, 1, 3]
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([3, 1, 1, 2, 1, 3, 3, 3])

# %%
df_motorola.head(100)
# Out:
#     memory  storage  selling_price_dolar
# 0       12      512                    3
# 1        8      128                    3
# 2       12      256                    3
# 3       12      256                    3
# 4       12      128                    3
# ..     ...      ...                  ...
# 95       1        8                    1
# 96      12      256                    3
# 97       4       64                    3
# 98       6       64                    3
# 99       3       32                    3
#
# [100 rows x 3 columns]
